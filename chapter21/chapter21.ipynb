# %%
import pandas as pd;
print(pd.__version__)

# %%
# pandas의 Series 메소드 / [85, 92, 78] -> 파라메탈.?
scores = pd.Series([85, 92, 78])
print(type(scores))
print(scores)

# %%
# 컬럼 - 2개 / row - 3개   (data는 항상 csv로 들고 와야함 이걸 DataFrame으로 만듦)
df = pd.DataFrame({
    "name": ["민수", "지영", "서준"],
    "score": [85, 92, 78],
})
print(df)

# %%
df.info()

# %%
df.describe()

# %%
df.shape
