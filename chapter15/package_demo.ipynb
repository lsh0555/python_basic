# %%
# shop은 패키지, price는 모듈, price 모듈에 있는 calculate_total, apply_discount라는 함수들
from shop.price import calculate_total, apply_discount

subtotal = calculate_total(12000, 3)
final_price = apply_discount(subtotal, 0.2) # 20% 할인
print(subtotal)
print(final_price)
# Out:
# 36000
# 28800.0
